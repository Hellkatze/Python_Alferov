# %%
a = float(input())
if a >= 0.0:
    print("+")
else:
    print("-")
# Out:
# 12.0

# %%
while True:
    a = float(input())
    if a > 0.0:
        print("+")
    elif a == 0:
            break
    else:
        print("-")

# %%
for i in range (1,51):
    if i %2 == 0:
        print(i*2)
    else:
        print(i/3)

# %%
import random
a = random.randint(1,100)
k = 0

for i in range(10):
    b = int(input("Input ur number:"))
    k+=1
    if b == a:
        print("Congratulation, u win in", k, "attempts")
        break
    elif b > a:
        print("Wrong, our number is lower, than ur. Attempts left:", 10-k)
        if k == 10:
            print("AhAHhAhA, u looose")
            break
    elif b < a:
        print("Wrong, our number is higher, than ur. Attempts left:", 10-k)
        if k == 10:
            print("AhAHhAhA, u looose")
            break

# %%
s = "Мама мыла раму."
k = 2
print(s[:k])
# Out:
# Ма

# %%
a, op, b = input().split()
a = float(a)
b = float(b)
if op == "+":
    print(a+b)
elif op === "-":
    print(a-b)
elif op == "*":
    print(a*b)
else:
    print(a/b)

# %%
x = float(input())
p = float(input())
y = float(input())

k = 0
n = 0

while n <= y:
    k+=1
    n=x*((1 + p/100)**k)
print(k)
