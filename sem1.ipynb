# %%
from numbers import Number

def get_min(input_list: list):
    
    assert isinstance(input_list, list), "Входной параметр не является списком"
    assert len(input_list) > 0, "Входной параметр является пустым списком"

    current_min = input_list[0]
    for i in input_list: 
        assert isinstance(i, (int, float, complex)) and not isinstance(i, bool), "Входной параметр содержит не только числовые данные"
        if i < current_min: 
            current_min = i 

    return current_min

ind = []

example_list = [-5,-4,4556,123,44,-5,0,324]
min_value = get_min(example_list)

d = min_value

for i, j in enumerate(example_list):
    if j == d:
        ind.append(i)

print(ind)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 19
#      16 ind = []
#      18 example_list = [-5,-4,4556,123,44,-5,0,324]
# ---> 19 min_value = get_min(example_list)
#      21 d = min_value
#      23 for i, j in enumerate(example_list):
#
# Cell In[44], line 5, in get_min(input_list)
#       3 def get_min(input_list: list):
# ----> 5     assert isinstance(input_list, list), "Входной параметр не является списком"
#       6     assert len(input_list) > 0, "Входной параметр является пустым списком"
#       8     current_min = input_list[0]
#
# TypeError: isinstance() arg 2 must be a type, a tuple of types, or a union

# %%
from random import randint


def puzirek(input_list: list):
   
    for i in range(len(input_list)-1):
        for j in range (len(input_list)-1-i):
            if input_list[j] > input_list[j+1]:
                input_list[j], input_list[j+1] = input_list[j+1], input_list[j]
    
    return input_list

massiv = [randint(0,1000) for i in range(10)]
test_m = puzirek(massiv)
print(test_m)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 14
#      11     return input_list
#      13 massiv = [randint(0,1000) for i in range(10)]
# ---> 14 test_m = puzirek(massiv)
#      15 print(test_m)
#
# Cell In[7], line 6, in puzirek(input_list)
#       4 def puzirek(input_list: list):
# ----> 6     for i in range(len(input_list)-1):
#       7         for j in range (len(input_list)-1-i):
#       8             if input_list[j] > input_list[j+1]:
#
# TypeError: 'int' object is not callable

# %%
import random

def generator(lenght, list):
    nuk = ['A', 'G', 'T', 'U', 'C']
    for i in range(lenght):
        list.append(random.choice(nuk))
    return list

len = int(input())
code = []
print("".join(generator(len, code)))
# Out:
# ATCUGACGAAGTAAT

# %%
import random

def rand(answer, k):
    for i in range(10):
        k+=1
        b = int(input("Input ur number:"))
        if b == answer:
            return print("Congratulation, u win in", k, "attempts")
            break
        elif b > answer:
            print("Wrong, our number is lower, than ur. Attempts left:", 10-k)
            if k == 10:
                return print("AhAHhAhA, u looose")
        elif b < answer:
            print("Wrong, our number is higher, than ur. Attempts left:", 10-k)
            if k == 10:
                return print("AhAHhAhA, u looose")

a = random.randint(1,100)
k = 0
rand(a, k)
# Out:
# Congratulation, u win in 1 attempts

# %%
def fib(n):
    if n == 0:
        return n
    elif n == 1:
        return n
    else:
        a, b = 0, 1
        for i in range(2, n + 1):
            a, b = b, a + b
        return b

n = int(input())
print(fib(n))
# Out:
# 0

# %%
def count_sw(d):
    s = 0
    for i in range(1, n):
        k = i
        while k > 0 and d[k] < d[k-1]:
            d[k], d[k-1] = d[k-1], d[k]
            s += 1
            k -= 1
    return s

n = int(input())
d = list(input().split())

print(count_sw(d))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 11
#       8             k -= 1
#       9     return s
# ---> 11 n = int(input())
#      12 d = list(input().split())
#      14 print(count_sw(d))
#
# ValueError: invalid literal for int() with base 10: ''
